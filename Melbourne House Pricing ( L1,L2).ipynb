# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:/Users/sriji/Sentdex ML/melbourne/Melbourne_housing_FULL.csv')
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0   3/9/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2   4/2/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3   4/2/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4   4/3/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
cols_to_use = ['Suburb','Address','Rooms','Landsize','SellerG','Bedroom2','Bathroom','Car','CouncilArea','Regionname','Price','Propertycount','Distance']
dataset = dataset[cols_to_use]
dataset.head()
# Out:
#        Suburb             Address  Rooms  Landsize SellerG  Bedroom2  \
# 0  Abbotsford       68 Studley St    2.0     126.0  Jellis       2.0
# 1  Abbotsford        85 Turner St    2.0     202.0  Biggin       2.0
# 2  Abbotsford     25 Bloomburg St    2.0     156.0  Biggin       2.0
# 3  Abbotsford  18/659 Victoria St    3.0       0.0  Rounds       3.0
# 4  Abbotsford        5 Charles St    3.0     134.0  Biggin       3.0
#
#    Bathroom  Car         CouncilArea             Regionname      Price  \
# 0       1.0  1.0  Yarra City Council  Northern Metropolitan        NaN
# 1       1.0  1.0  Yarra City Council  Northern Metropolitan  1480000.0
# 2       1.0  0.0  Yarra City Council  Northern Metropolitan  1035000.0
# 3       2.0  1.0  Yarra City Council  Northern Metropolitan        NaN
# 4       2.0  0.0  Yarra City Council  Northern Metropolitan  1465000.0
#
#    Propertycount  Distance
# 0         4019.0       2.5
# 1         4019.0       2.5
# 2         4019.0       2.5
# ...

# %%
cols_to_fill_zero = ['Propertycount','Bedroom2','Distance','Bathroom','Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)
dataset.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Landsize         11810
# SellerG              0
# Bedroom2             0
# Bathroom             0
# Car                  0
# CouncilArea          3
# Regionname           3
# Price             7610
# Propertycount        0
# Distance             0
# dtype: int64

# %%
dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())

# %%
dataset.dropna(inplace=True)
dataset.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Landsize         0
# SellerG          0
# Bedroom2         0
# Bathroom         0
# Car              0
# CouncilArea      0
# Regionname       0
# Price            0
# Propertycount    0
# Distance         0
# dtype: int64

# %%
dataset.head()
# Out:
#        Suburb           Address  Rooms  Landsize SellerG  Bedroom2  Bathroom  \
# 1  Abbotsford      85 Turner St      2     202.0  Biggin       2.0       1.0
# 2  Abbotsford   25 Bloomburg St      2     156.0  Biggin       2.0       1.0
# 4  Abbotsford      5 Charles St      3     134.0  Biggin       3.0       2.0
# 5  Abbotsford  40 Federation La      3      94.0  Biggin       3.0       2.0
# 6  Abbotsford       55a Park St      4     120.0  Nelson       3.0       1.0
#
#    Car         CouncilArea             Regionname      Price  Propertycount  \
# 1  1.0  Yarra City Council  Northern Metropolitan  1480000.0         4019.0
# 2  0.0  Yarra City Council  Northern Metropolitan  1035000.0         4019.0
# 4  0.0  Yarra City Council  Northern Metropolitan  1465000.0         4019.0
# 5  1.0  Yarra City Council  Northern Metropolitan   850000.0         4019.0
# 6  2.0  Yarra City Council  Northern Metropolitan  1600000.0         4019.0
#
#    Distance
# 1       2.5
# 2       2.5
# ...

# %%
x = dataset.drop('Price',axis = 1)
y = dataset.Price

# %%
x.head()
# Out:
#        Suburb           Address  Rooms  Landsize SellerG  Bedroom2  Bathroom  \
# 1  Abbotsford      85 Turner St    2.0     202.0  Biggin       2.0       1.0
# 2  Abbotsford   25 Bloomburg St    2.0     156.0  Biggin       2.0       1.0
# 4  Abbotsford      5 Charles St    3.0     134.0  Biggin       3.0       2.0
# 5  Abbotsford  40 Federation La    3.0      94.0  Biggin       3.0       2.0
# 6  Abbotsford       55a Park St    4.0     120.0  Nelson       3.0       1.0
#
#    Car         CouncilArea             Regionname  Propertycount  Distance
# 1  1.0  Yarra City Council  Northern Metropolitan         4019.0       2.5
# 2  0.0  Yarra City Council  Northern Metropolitan         4019.0       2.5
# 4  0.0  Yarra City Council  Northern Metropolitan         4019.0       2.5
# 5  1.0  Yarra City Council  Northern Metropolitan         4019.0       2.5
# 6  2.0  Yarra City Council  Northern Metropolitan         4019.0       2.5

# %%
y.head()
# Out:
# 1    1480000.0
# 2    1035000.0
# 4    1465000.0
# 5     850000.0
# 6    1600000.0
# Name: Price, dtype: float64

# %%
dataset = pd.get_dummies(dataset,drop_first = True)
dataset.head()
dataset.drop('Propertycount',axis=1)
dataset.head()
# Out:
#    Rooms  Landsize  Bedroom2  Bathroom  Car      Price  Propertycount  \
# 1    2.0     202.0       2.0       1.0  1.0  1480000.0         4019.0
# 2    2.0     156.0       2.0       1.0  0.0  1035000.0         4019.0
# 4    3.0     134.0       3.0       2.0  0.0  1465000.0         4019.0
# 5    3.0      94.0       3.0       2.0  1.0   850000.0         4019.0
# 6    4.0     120.0       3.0       1.0  2.0  1600000.0         4019.0
#
#    Distance  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 1       2.5                  0                    0  ...
# 2       2.5                  0                    0  ...
# 4       2.5                  0                    0  ...
# 5       2.5                  0                    0  ...
# 6       2.5                  0                    0  ...
#
#    CouncilArea_Wyndham City Council  CouncilArea_Yarra City Council  \
# 1                                 0                               1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
len(X_train)
# Out:
# 21795

# %%
len(y_train)
# Out:
# 21795

# %%
reg = LinearRegression().fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 reg = LinearRegression().fit(X_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...
